# %%
from nlp import load_dataset

# %%
dataset = load_dataset('csv', data_files='.data/yelp_review_polarity_csv/train.csv',column_names=['label','txt'])
# Out:
# ...
# Using custom data configuration default
# ...
# Dataset csv downloaded and prepared to /Users/yonatang/.cache/huggingface/datasets/csv/default/0.0.0. Subsequent calls will reuse this data.

# %%
dataset
# Out:
# {'train': Dataset(schema: {'label': 'int64', 'txt': 'string'}, num_rows: 560000)}
